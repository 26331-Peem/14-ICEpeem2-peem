# %% [markdown]
# <a href="https://colab.research.google.com/github/26331-Peem/14-ICEpeem2-peem/blob/main/final14_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("สวัสดีครับ ยินดีต้อนรับสู่ โปรเเกรมตรวจสอบเลขคู่ เลขคี่")
print("กระผมชื่อ นายชัชวินทร์ ศิริโภคา เลขที่14 ม.4/4")

number = int(input("กรอกตัวเลข: "))

if number %2 == 0:
   print("เลขคู่")
else:
   print("เลขคี่")
# Out:
# สวัสดีครับ ยินดีต้อนรับสู่ โปรเเกรมตรวจสอบเลขคู่ เลขคี่
# กระผมชื่อ นายชัชวินทร์ ศิริโภคา เลขที่14 ม.4/4
# กรอกตัวเลข: 8
# เลขคู่
