# %% [markdown]
# <a href="https://colab.research.google.com/github/26331-Peem/14-ICEpeem2-peem/blob/main/final14_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("=" * 50)
print("โปรแกรมตรวจสอบเลขคู่ - เลขคี่")
print("=" * 50)

while True:
    try:
        number = int(input("กรอกตัวเลข (หรือพิมพ์ 0 เพื่อออก): "))

        if number == 0:
            print("ออกจากโปรแกรมเรียบร้อยแล้ว 👋")
            break

        if number % 2 == 0:
            print(f"{number} เป็นเลขคู่ ✅")
        else:
            print(f"{number} เป็นเลขคี่ 🔹")

    except ValueError:
        print("กรุณากรอก 'ตัวเลขจำนวนเต็ม' เท่านั้น ❗")

    print("-" * 50)
# Out:
# ...
# โปรแกรมตรวจสอบเลขคู่ - เลขคี่
# ...
# กรอกตัวเลข (หรือพิมพ์ 0 เพื่อออก): 5
# 5 เป็นเลขคี่ 🔹
# --------------------------------------------------
# กรอกตัวเลข (หรือพิมพ์ 0 เพื่อออก): 6
# 6 เป็นเลขคู่ ✅
# --------------------------------------------------
# กรอกตัวเลข (หรือพิมพ์ 0 เพื่อออก): 0
# ออกจากโปรแกรมเรียบร้อยแล้ว 👋
